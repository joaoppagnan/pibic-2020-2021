# %% [markdown]
# # Implementando uma GRU com Grid Search para escolher melhor os parâmetros no sistema de Mackey-Glass

# %% [markdown]
# ## 1. Importando as bibliotecas necessárias

# %% [markdown]
# ### 1.1 Bibliotecas gerais

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns # a biblioteca 'seaborn' contém vários estilos para os gráficos do 'matpĺotlib'

# agora, melhoramos a qualidade de saida e de visualizacao da imagem 
# alem de mudar a fonte padrao para uma do latex
sns.set_style("ticks")
plt.rcParams['savefig.dpi'] = 200
plt.rcParams["figure.dpi"] = 125

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Palatino"],
})
plt.style.use('dark_background')

import sys 
sys.path.insert(0, '../../../scripts')

# %% [markdown]
# ### 1.2 Bibliotecas para GRU

# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')

from tensorflow import keras

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit # para gridsearch com holdout

# o holdout são os últimos valores do vetor de dados de treino
# a cada divisão do timeseriessplit, o conjunto de treino incorpora mais dados do conjunto de teste

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor

# %%
import gru_model as gru

# %% [markdown]
# ### 1.3 Bibliotecas dos sistemas caóticos

# %%
import timeseries as times
import mackeyglassequations as mgeq

# %% [markdown]
# ## 2. Gerando a série temporal

# %%
t_inicial = 0
t_final = 5000
tau = 22
n = 10
gamma = 0.1
beta = 0.2
theta = 1

# %%
macglass = mgeq.MackeyGlass(tau=tau, gamma=gamma, beta=beta, n=n, theta=theta)

# %%
solucoes, instantes_temporais = macglass.calcular(t_inicial = t_inicial, t_final = t_final)
# Out:
# Generating, compiling, and loading C code.
# Using default integration parameters.

# %% [markdown]
# ### Série Temporal de Mackey-Glass

# %%
fig, ax = plt.subplots()
ax.set_title('Série temporal de 0 a 600 dias da equação de Mackey-Glass para\n' + r'$\tau =$ ' + str(tau) + r', $\beta =$ ' + str(beta) + r', $\gamma =$ ' + str(gamma) + r', $n =$ ' + str(n) + r' e $\theta =$ ' + str(theta) + ' utilizando $P(0) =$ ' + str(0.1*theta))
ax.plot(instantes_temporais, solucoes, color='Gold', linewidth=0.9)

ax.set_ylabel('$P(t)$')
ax.set_xlabel('$t$')
ax.set_xlim(0,600)
    
ax.grid(True)

fig.tight_layout()
sns.despine()
plt.show()

# %%
x = np.array(solucoes)
x = np.reshape(x, (1, len(x)))
x = x[0]

# %% [markdown]
# ### 2.1 Dividindo em um conjunto de treinamento e de teste, para K = 4 e L = 3

# %%
K = 4
L = 3
tam_teste = 0.15

# %%
serie_temporal = times.SerieTemporal(x, K=K, L=L)

# %%
X_treino, X_teste, y_treino, y_teste = serie_temporal.dividir_treino_teste(tam_teste)

# %% [markdown]
# ### 2.2 Pré-processamento nos dados de entrada

# %%
len_treino = X_treino.shape[0]
len_teste = X_teste.shape[0]
n_samples = X_treino.shape[1]

# %%
X_treino = np.reshape(X_treino,(len_treino, n_samples, 1))
X_teste = np.reshape(X_teste,(len_teste, n_samples, 1))

# %% [markdown]
# ## 3. Definindo o modelo para a GRU e executando os Gridsearches

# %%
holdout = TimeSeriesSplit(n_splits=4, test_size=int(0.1*len(y_treino)), gap=0)

# %% [markdown]
# ### 3.1 Criando o objeto da GRU

# %%
gru_gridsearch = gru.ModeloGRU(input_shape = (K, 1))

# %% [markdown]
# Utilizaremos os seguintes parâmetros no *Grid Search*:

# %%
param_grid = dict(batch_size=[2, 4, 8, 16, 32], 
                  init_mode = ['glorot_normal', 'glorot_uniform'],
                  n_units = [5, 10, 15, 20, 30, 50, 75, 100],
                  learning_rate = [0.001, 0.003, 0.005, 0.008, 0.01])

# %% [markdown]
# Para facilitar, dividiremos esse processo em etapas.

# %% [markdown]
# ### 3.2 Definindo parâmetros que não serão definidos pelo *Grid Search*

# %%
loss = "mean_squared_error"
optimizer = keras.optimizers.Nadam()

# %% [markdown]
# ### 3.3 Definindo e executando o primeiro *Grid Search*

# %% [markdown]
# Primeiro, avaliaremos o impacto do *batch size*.

# %%
param_grid_1 = dict(batch_size=[2, 4, 8, 16, 32])

# %%
model_cv_1 = KerasRegressor(build_fn=gru_gridsearch.gridsearch, epochs=100, verbose=0)

# %%
grid = GridSearchCV(estimator=model_cv_1, param_grid=param_grid_1, n_jobs=1, cv=holdout, scoring='neg_mean_squared_error', verbose=2)

# %%
grid_result = grid.fit(X_treino, y_treino)
# Out:
# Fitting 4 folds for each of 5 candidates, totalling 20 fits
# [CV] END .......................................batch_size=2; total time= 2.6min
# [CV] END .......................................batch_size=2; total time= 3.0min
# [CV] END .......................................batch_size=2; total time= 3.4min
# [CV] END .......................................batch_size=2; total time= 3.8min
# [CV] END .......................................batch_size=4; total time= 1.3min
# [CV] END .......................................batch_size=4; total time= 1.5min
# [CV] END .......................................batch_size=4; total time= 1.7min
# [CV] END .......................................batch_size=4; total time= 1.9min
# [CV] END .......................................batch_size=8; total time=  45.7s
# [CV] END .......................................batch_size=8; total time=  52.6s
# [CV] END .......................................batch_size=8; total time=  60.0s
# [CV] END .......................................batch_size=8; total time= 1.1min
# [CV] END ......................................batch_size=16; total time=  23.7s
# [CV] END ......................................batch_size=16; total time=  26.9s
# [CV] END ......................................batch_size=16; total time=  31.2s
# [CV] END ......................................batch_size=16; total time=  34.0s
# [CV] END ......................................batch_size=32; total time=  12.5s
# [CV] END ......................................batch_size=32; total time=  14.4s
# [CV] END ......................................batch_size=32; total time=  16.0s
# [CV] END ......................................batch_size=32; total time=  18.0s

# %%
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: -0.000105 using {'batch_size': 2}

# %%
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# -0.000105 (0.000011) with: {'batch_size': 2}
# -0.000229 (0.000090) with: {'batch_size': 4}
# -0.000381 (0.000163) with: {'batch_size': 8}
# -0.000532 (0.000146) with: {'batch_size': 16}
# -0.000987 (0.000490) with: {'batch_size': 32}

# %% [markdown]
# ### 3.4 Definindo e executando o segundo *Grid Search*

# %% [markdown]
# Agora, avaliaremos o impacto do *learning rate* do otimizador.

# %%
model_cv_2 = KerasRegressor(build_fn=gru_gridsearch.gridsearch, epochs=100, verbose=0, batch_size=2)

# %%
param_grid_2 = dict(learning_rate=[0.001, 0.003, 0.005, 0.008, 0.01])

# %%
grid = GridSearchCV(estimator=model_cv_2, param_grid=param_grid_2, n_jobs=1, cv=holdout, scoring='neg_mean_squared_error', verbose=2)

# %%
grid_result = grid.fit(X_treino, y_treino)
# Out:
# Fitting 4 folds for each of 5 candidates, totalling 20 fits
# [CV] END ................................learning_rate=0.001; total time= 3.0min
# [CV] END ................................learning_rate=0.001; total time= 3.0min
# [CV] END ................................learning_rate=0.001; total time= 3.4min
# [CV] END ................................learning_rate=0.001; total time= 4.1min
# [CV] END ................................learning_rate=0.003; total time= 2.8min
# [CV] END ................................learning_rate=0.003; total time= 3.1min
# [CV] END ................................learning_rate=0.003; total time= 3.8min
# [CV] END ................................learning_rate=0.003; total time= 4.3min
# [CV] END ................................learning_rate=0.005; total time= 2.8min
# [CV] END ................................learning_rate=0.005; total time= 3.3min
# [CV] END ................................learning_rate=0.005; total time= 3.8min
# [CV] END ................................learning_rate=0.005; total time= 4.2min
# [CV] END ................................learning_rate=0.008; total time= 2.8min
# [CV] END ................................learning_rate=0.008; total time= 3.3min
# [CV] END ................................learning_rate=0.008; total time= 3.8min
# [CV] END ................................learning_rate=0.008; total time= 4.3min
# [CV] END .................................learning_rate=0.01; total time= 2.8min
# [CV] END .................................learning_rate=0.01; total time= 3.2min
# [CV] END .................................learning_rate=0.01; total time= 3.8min
# [CV] END .................................learning_rate=0.01; total time= 4.2min

# %%
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: -0.000096 using {'learning_rate': 0.005}

# %%
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# -0.000190 (0.000072) with: {'learning_rate': 0.001}
# -0.000139 (0.000033) with: {'learning_rate': 0.003}
# -0.000096 (0.000007) with: {'learning_rate': 0.005}
# -0.000238 (0.000139) with: {'learning_rate': 0.008}
# -0.000226 (0.000086) with: {'learning_rate': 0.01}

# %% [markdown]
# ### 3.5 Definindo e executando o terceiro *Grid Search*

# %% [markdown]
# Agora, avaliaremos o impacto do inicializador da camada intermediária, considerando a $\tanh$ como função de ativação.

# %%
model_cv_3 = KerasRegressor(build_fn=gru_gridsearch.gridsearch, epochs=100, verbose=0, batch_size=2, learning_rate=0.005)

# %%
param_grid_3 = dict(init_mode = ['glorot_uniform', 'glorot_normal'])

# %%
grid = GridSearchCV(estimator=model_cv_3, param_grid=param_grid_3, n_jobs=1, cv=holdout, scoring='neg_mean_squared_error', verbose=2)

# %%
grid_result = grid.fit(X_treino, y_treino)
# Out:
# Fitting 4 folds for each of 2 candidates, totalling 8 fits
# [CV] END ...........................init_mode=glorot_uniform; total time= 2.6min
# [CV] END ...........................init_mode=glorot_uniform; total time= 3.0min
# [CV] END ...........................init_mode=glorot_uniform; total time= 4.4min
# [CV] END ...........................init_mode=glorot_uniform; total time= 5.7min
# [CV] END ............................init_mode=glorot_normal; total time= 2.8min
# [CV] END ............................init_mode=glorot_normal; total time= 3.3min
# [CV] END ............................init_mode=glorot_normal; total time= 3.6min
# [CV] END ............................init_mode=glorot_normal; total time= 4.1min

# %%
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: -0.000120 using {'init_mode': 'glorot_uniform'}

# %%
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# -0.000120 (0.000047) with: {'init_mode': 'glorot_uniform'}
# -0.000128 (0.000057) with: {'init_mode': 'glorot_normal'}

# %% [markdown]
# ### 3.6 Definindo e executando o quarto *Grid Search*

# %% [markdown]
# Agora, avaliaremos o número de unidades *GRU* na camada intermediária.

# %%
model_cv_4 = KerasRegressor(build_fn=gru_gridsearch.gridsearch, epochs=100, verbose=0, batch_size=2, learning_rate=0.005, init_mode='glorot_uniform')

# %%
param_grid_4 = dict(n_units = [5, 10, 15, 20, 30, 50, 75, 100])

# %%
grid = GridSearchCV(estimator=model_cv_4, param_grid=param_grid_4, n_jobs=1, cv=holdout, scoring='neg_mean_squared_error', verbose=2)

# %%
grid_result = grid.fit(X_treino, y_treino)
# Out:
# Fitting 4 folds for each of 8 candidates, totalling 32 fits
# [CV] END ..........................................n_units=5; total time= 2.7min
# [CV] END ..........................................n_units=5; total time= 3.2min
# [CV] END ..........................................n_units=5; total time= 3.5min
# [CV] END ..........................................n_units=5; total time= 4.2min
# [CV] END .........................................n_units=10; total time= 3.5min
# [CV] END .........................................n_units=10; total time= 3.3min
# [CV] END .........................................n_units=10; total time= 3.4min
# [CV] END .........................................n_units=10; total time= 3.8min
# [CV] END .........................................n_units=15; total time= 2.6min
# [CV] END .........................................n_units=15; total time= 3.0min
# [CV] END .........................................n_units=15; total time= 3.4min
# [CV] END .........................................n_units=15; total time= 3.8min
# [CV] END .........................................n_units=20; total time= 2.5min
# [CV] END .........................................n_units=20; total time= 3.0min
# [CV] END .........................................n_units=20; total time= 3.6min
# [CV] END .........................................n_units=20; total time= 3.8min
# [CV] END .........................................n_units=30; total time= 2.6min
# [CV] END .........................................n_units=30; total time= 3.1min
# [CV] END .........................................n_units=30; total time= 3.7min
# [CV] END .........................................n_units=30; total time= 4.8min
# [CV] END .........................................n_units=50; total time= 3.7min
# [CV] END .........................................n_units=50; total time= 3.3min
# [CV] END .........................................n_units=50; total time= 4.0min
# [CV] END .........................................n_units=50; total time= 4.5min
# [CV] END .........................................n_units=75; total time= 3.0min
# [CV] END .........................................n_units=75; total time= 3.6min
# [CV] END .........................................n_units=75; total time= 3.7min
# [CV] END .........................................n_units=75; total time= 4.0min
# [CV] END ........................................n_units=100; total time= 2.6min
# [CV] END ........................................n_units=100; total time= 3.1min
# [CV] END ........................................n_units=100; total time= 3.7min
# [CV] END ........................................n_units=100; total time= 4.1min

# %%
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: -0.000101 using {'n_units': 10}

# %%
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# -0.000283 (0.000189) with: {'n_units': 5}
# -0.000101 (0.000016) with: {'n_units': 10}
# -0.000129 (0.000033) with: {'n_units': 15}
# -0.000167 (0.000104) with: {'n_units': 20}
# -0.000151 (0.000055) with: {'n_units': 30}
# -0.000136 (0.000066) with: {'n_units': 50}
# -0.000211 (0.000121) with: {'n_units': 75}
# -0.000147 (0.000015) with: {'n_units': 100}

# %% [markdown]
# ### Treino com o melhor modelo

# %% [markdown]
# #### Dados de entrada

# %%
X_treino, X_teste, X_val, y_treino, y_teste, y_val = serie_temporal.dividir_treino_teste_validacao(tam_teste=0.15, tam_val=0.1)

# %% [markdown]
# #### Ajuste no modelo

# %%
model = gru.ModeloGRU(input_shape = (K, 1), name='GRU-mackey-glass')

# %%
model.criar_modelo(n_units=10, init_mode='glorot_uniform')

# %%
model.montar(learning_rate=0.005)

# %%
model.visualizar()
# Out:
# Model: "GRU-mackey-glass"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# camada_gru (GRU)             (None, 10)                390
# _________________________________________________________________
# camada_de_saida (Dense)      (None, 1)                 11
# =================================================================
# Total params: 401
# Trainable params: 401
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.treinar(X_treino, X_val, y_treino, y_val, batch_size=2)
# Out:
# Epoch 1/100
# 1910/1910 [==============================] - 5s 2ms/step - loss: 0.0317 - val_loss: 0.0031
# Epoch 2/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 3/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 4/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 0.0011 - val_loss: 6.8466e-04
# Epoch 5/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 8.8768e-04 - val_loss: 7.2738e-04
# Epoch 6/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 7.4042e-04 - val_loss: 6.3048e-04
# Epoch 7/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 6.9128e-04 - val_loss: 8.4259e-04
# Epoch 8/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 6.9008e-04 - val_loss: 8.1155e-04
# Epoch 9/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 6.1388e-04 - val_loss: 4.7383e-04
# Epoch 10/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 5.7163e-04 - val_loss: 4.2757e-04
# Epoch 11/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 5.7126e-04 - val_loss: 5.6662e-04
# Epoch 12/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 5.2403e-04 - val_loss: 5.0018e-04
# Epoch 13/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 4.8494e-04 - val_loss: 7.0839e-04
# Epoch 14/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 4.9148e-04 - val_loss: 4.1958e-04
# Epoch 15/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 4.8576e-04 - val_loss: 0.0016
# Epoch 16/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 4.5535e-04 - val_loss: 2.8858e-04
# Epoch 17/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 4.3201e-04 - val_loss: 3.2259e-04
# Epoch 18/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 4.1442e-04 - val_loss: 5.3290e-04
# Epoch 19/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 3.9067e-04 - val_loss: 6.9302e-04
# Epoch 20/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 3.8940e-04 - val_loss: 3.3094e-04
# Epoch 21/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 3.7795e-04 - val_loss: 3.0704e-04
# Epoch 22/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 3.7127e-04 - val_loss: 5.6599e-04
# Epoch 23/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 3.8196e-04 - val_loss: 2.4748e-04
# Epoch 24/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 3.3970e-04 - val_loss: 3.3438e-04
# Epoch 25/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 3.6016e-04 - val_loss: 2.0608e-04
# Epoch 26/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 3.2523e-04 - val_loss: 3.8198e-04
# Epoch 27/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 3.3373e-04 - val_loss: 2.0833e-04
# Epoch 28/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 2.8495e-04 - val_loss: 3.1109e-04
# Epoch 29/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 2.8602e-04 - val_loss: 3.1432e-04
# Epoch 30/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 2.8633e-04 - val_loss: 5.2661e-04
# Epoch 31/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 2.8786e-04 - val_loss: 3.1170e-04
# Epoch 32/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 2.6197e-04 - val_loss: 7.7834e-04
# Epoch 33/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 2.6547e-04 - val_loss: 3.8387e-04
# Epoch 34/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 2.5119e-04 - val_loss: 1.8012e-04
# Epoch 35/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 2.8001e-04 - val_loss: 2.0681e-04
# Epoch 36/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 2.4752e-04 - val_loss: 2.3816e-04
# Epoch 37/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 2.4062e-04 - val_loss: 1.8088e-04
# Epoch 38/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 2.5587e-04 - val_loss: 1.4547e-04
# Epoch 39/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 2.3167e-04 - val_loss: 1.9103e-04
# Epoch 40/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 2.3927e-04 - val_loss: 5.3800e-04
# Epoch 41/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 2.2954e-04 - val_loss: 4.3444e-04
# Epoch 42/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 2.3235e-04 - val_loss: 3.4963e-04
# Epoch 43/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 2.3337e-04 - val_loss: 1.6704e-04
# Epoch 44/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 2.2974e-04 - val_loss: 1.7584e-04
# Epoch 45/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 2.3514e-04 - val_loss: 3.7161e-04
# Epoch 46/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 2.1948e-04 - val_loss: 2.4198e-04
# Epoch 47/100
# 1910/1910 [==============================] - 3s 2ms/step - loss: 2.1544e-04 - val_loss: 3.2143e-04
# Epoch 48/100
# 1910/1910 [==============================] - 4s 2ms/step - loss: 2.3522e-04 - val_loss: 1.5670e-04

# %% [markdown]
# ## Teste com o melhor modelo

# %%
y_pred = model.predicao(X_teste)

# %% [markdown]
# ### Gráfico

# %%
fig, ax = plt.subplots()
ax.plot(instantes_temporais[len(instantes_temporais)-int(len(instantes_temporais)*tam_teste):,], y_teste, color='Gold', label='Valor real', linewidth=0.9)
ax.plot(instantes_temporais[len(instantes_temporais)-int(len(instantes_temporais)*tam_teste):,], y_pred, color='Silver', label='GRU', linewidth=0.9)

ax.set_title("Comparação da predição da GRU com o valor real das equações de Mackey-Glass\n utilizando a rede recorrente LSTM no conjunto de teste")
ax.set_ylabel('$P(t)$')
ax.set_xlabel('$t$')
ax.set_xlim(4250, 5000)
    
ax.grid(True)
sns.despine()
ax.legend()

plt.show()
fig.savefig("../../../images/gru/performance/gru-vs-mackeyglass.png")
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ### Erro Quadrático Médio

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_teste, y_pred)
print("MSE = " + str(mse))
# Out:
# MSE = 0.00014190801003349725

# %% [markdown]
# ### Salvando o Modelo

# %%
model.salvar("../../../models/gru/gru-mackeyglass", h5="ON")
# Out:
# O modelo foi salvo!
