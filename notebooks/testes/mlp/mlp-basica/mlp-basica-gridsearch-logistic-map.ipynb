# %% [markdown]
# # Implementando uma MLP básica com Grid Search para escolher melhor os parâmetros

# %% [markdown]
# ## 1. Importando as bibliotecas necessárias

# %% [markdown]
# ### 1.1 Bibliotecas gerais

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns # a biblioteca 'seaborn' contém vários estilos para os gráficos do 'matpĺotlib'

# agora, melhoramos a qualidade de saida e de visualizacao da imagem 
# alem de mudar a fonte padrao para uma do latex
sns.set_style("ticks")
plt.rcParams['savefig.dpi'] = 200
plt.rcParams["figure.dpi"] = 100

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Palatino"],
})
plt.style.use('dark_background')

# %% [markdown]
# ### 1.2 Bibliotecas para MLP

# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

from tensorflow import keras

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

from tensorboard.plugins.hparams import api as hp

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor

# %% [markdown]
# ### 1.3 Bibliotecas dos sistemas caóticos

# %%
import sys 
sys.path.insert(0, '../../../../scripts')

import timeseries as times
import logisticmap as logmap

# %% [markdown]
# ## 2. Gerando a série temporal do mapa logístico

# %% [markdown]
# Os valores para os parâmetros das equações serão os "básicos" apresentados no *paper* original. Utilizaremos  $\tau = 22$, o que faz com que o sistemas esteja em caos.

# %%
x_inicial = 0.5
n_inicial = 0
n_iteracoes = 1000
r=3.9
estados = np.array([x_inicial, n_inicial])

# %%
mapa = logmap.MapaLogistico(estado_inicial=estados, r=r)

# %%
for n in range(0, n_iteracoes):
    mapa.iterar()
    estados = np.vstack((estados, mapa.ler_estado()))

# %%
x = estados[:, 0]
n = estados[:, 1]

# %%
fig, ax = plt.subplots()
ax.plot(n, x, color='DeepSkyBlue')

ax.set_title("100 iterações iniciais da série temporal do Mapa Logístico para $r = $" + str(r) + " \n com $x_{0} =$ " + str(x[0]))
ax.set_ylabel('x')
ax.set_xlabel('n')
ax.set_xlim(0,100)
    
ax.grid(True)
sns.despine()

plt.show()

# %% [markdown]
# ### 2.1 Dividindo em um conjunto de treinamento e de teste, para K = 4 e L = 3

# %%
K = 4
L = 3
tam_teste = 0.1

# %%
serie_temporal = times.SerieTemporal(x, K=K, L=L)

# %%
serie_temporal.criar_matrizes()

# %%
X_treino, X_teste, y_treino, y_teste = serie_temporal.dividir_treino_teste(tam_teste)

# %% [markdown]
# ## 3. Definindo o modelo para a MLP

# %% [markdown]
# ### 3.1 Definindo parâmetros que não serão definidos pelo Grid Search

# %%
param_grid = dict(batch_size=[1, 2, 4, 8, 16, 24, 32, 48, 64, 128], 
                  batch_normalization=['ON', 'OFF'], 
                  activation=['selu', 'relu', 'elu', 'sigmoid', 'tanh', 'logitic'], 
                  init_mode = ['lecun_uniform', 'lecun_normal', 'glorot_normal', 'glorot_uniform', 'he_normal', 'he_uniform'],
                  learnig_rate = [0.001, 0.003, 0.005, 0.008, 0.01])

# %%
loss = "mean_squared_error"
optimizer = keras.optimizers.Nadam()
metrics = tf.keras.metrics.RootMeanSquaredError()

# %%
early_stopping_cv = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True, monitor='root_mean_squared_error')

# %% [markdown]
# ### 3.2 Definindo as primeiras métricas a serem avaliadas pelo Grid Search

# %% [markdown]
# Primeiro, avaliaremos o impacto do *batch size*, da função de ativação e da inicialização dos neurônios, e a taxa de aprendizado. O número de épocas será determinado quando formos treinar a rede, através do *early stopping*.

# %%
param_grid_1 = dict(batch_size=[2, 4, 8, 16, 24, 32, 64, 128], 
                  batch_normalization=['ON', 'OFF'])

# %% [markdown]
# ### 3.2 Definindo função para criar a MLP

# %%
def criar_modelo(batch_normalization='ON', learning_rate=0.001, activation='selu', init_mode='lecun_normal', n_neurons=30):
    
    optimizer_gs = optimizer
    optimizer_gs.learning_rate.assign(learning_rate)
    
    model = keras.Sequential()
    model.add(keras.layers.Dense(K, input_dim=K, name="camada_de_entrada", activation = 'linear'))
    if (batch_normalization == 'ON'):
        model.add(keras.layers.BatchNormalization(name="camada_de_batch_normalization"))
    model.add(keras.layers.Dense(n_neurons, input_dim=K, activation=activation, kernel_initializer=init_mode, name="camada_intermediaria"))
    model.add(keras.layers.Dense(1, activation='linear', name="camada_de_saida"))
    
    model.compile(
        optimizer = optimizer_gs,
        loss = loss,
        metrics = metrics)
    
    model.build()
    return model

# %%
model_cv_1 = KerasRegressor(build_fn=criar_modelo, epochs=100, verbose=0)

# %%
grid = GridSearchCV(estimator=model, param_grid=param_grid_1, n_jobs=1, cv=4)

# %%
grid_result = grid.fit(X_treino, y_treino, callbacks=early_stopping_cv)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7fc57c7a53a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fc6af703550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7fc5b817c5e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7fc6af7034c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fc59835f1f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: -0.030302 using {'batch_normalization': 'OFF', 'batch_size': 2}

# %% [markdown]
# ### Treino com o melhor modelo

# %%
model = criar_modelo(batch_normalization='ON')

# %%
model.summary()
# Out:
# Model: "sequential_75"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# camada_de_entrada (Dense)    (None, 4)                 20
# _________________________________________________________________
# camada_de_batch_normalizatio (None, 4)                 16
# _________________________________________________________________
# camada_intermediaria (Dense) (None, 30)                150
# _________________________________________________________________
# camada_de_saida (Dense)      (None, 1)                 31
# =================================================================
# Total params: 217
# Trainable params: 209
# Non-trainable params: 8
# _________________________________________________________________

# %%
X_treino, X_val, y_treino, y_val = train_test_split(X_treino, y_treino, test_size=0.1)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss')

# %%
batch_size = 32

# %%
history = model.fit(X_treino, y_treino, epochs=100,
                            callbacks=early_stopping, validation_data=(X_val, y_val),
                            batch_size=batch_size)
treinamento = pd.DataFrame(history.history)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 1s 7ms/step - loss: 0.4171 - root_mean_squared_error: 0.5453 - val_loss: 0.1666 - val_root_mean_squared_error: 0.4082
# Epoch 2/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1176 - root_mean_squared_error: 0.3428 - val_loss: 0.1085 - val_root_mean_squared_error: 0.3294
# Epoch 3/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1002 - root_mean_squared_error: 0.3166 - val_loss: 0.1131 - val_root_mean_squared_error: 0.3363
# Epoch 4/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0971 - root_mean_squared_error: 0.3115 - val_loss: 0.1087 - val_root_mean_squared_error: 0.3297
# Epoch 5/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0908 - root_mean_squared_error: 0.3014 - val_loss: 0.1036 - val_root_mean_squared_error: 0.3219
# Epoch 6/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0786 - root_mean_squared_error: 0.2803 - val_loss: 0.0910 - val_root_mean_squared_error: 0.3017
# Epoch 7/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0877 - root_mean_squared_error: 0.2961 - val_loss: 0.1003 - val_root_mean_squared_error: 0.3166
# Epoch 8/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0774 - root_mean_squared_error: 0.2779 - val_loss: 0.0989 - val_root_mean_squared_error: 0.3145
# Epoch 9/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0771 - root_mean_squared_error: 0.2777 - val_loss: 0.0903 - val_root_mean_squared_error: 0.3004
# Epoch 10/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0825 - root_mean_squared_error: 0.2872 - val_loss: 0.0925 - val_root_mean_squared_error: 0.3041
# Epoch 11/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0834 - root_mean_squared_error: 0.2887 - val_loss: 0.0866 - val_root_mean_squared_error: 0.2943
# Epoch 12/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0745 - root_mean_squared_error: 0.2729 - val_loss: 0.0837 - val_root_mean_squared_error: 0.2893
# Epoch 13/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0745 - root_mean_squared_error: 0.2728 - val_loss: 0.0821 - val_root_mean_squared_error: 0.2866
# Epoch 14/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0831 - root_mean_squared_error: 0.2880 - val_loss: 0.0858 - val_root_mean_squared_error: 0.2930
# Epoch 15/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0721 - root_mean_squared_error: 0.2684 - val_loss: 0.0764 - val_root_mean_squared_error: 0.2763
# Epoch 16/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0725 - root_mean_squared_error: 0.2691 - val_loss: 0.0734 - val_root_mean_squared_error: 0.2708
# Epoch 17/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0727 - root_mean_squared_error: 0.2694 - val_loss: 0.0756 - val_root_mean_squared_error: 0.2750
# Epoch 18/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0795 - root_mean_squared_error: 0.2819 - val_loss: 0.0723 - val_root_mean_squared_error: 0.2688
# Epoch 19/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0668 - root_mean_squared_error: 0.2581 - val_loss: 0.0678 - val_root_mean_squared_error: 0.2605
# Epoch 20/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0690 - root_mean_squared_error: 0.2626 - val_loss: 0.0660 - val_root_mean_squared_error: 0.2569
# Epoch 21/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0697 - root_mean_squared_error: 0.2638 - val_loss: 0.0641 - val_root_mean_squared_error: 0.2532
# Epoch 22/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0707 - root_mean_squared_error: 0.2658 - val_loss: 0.0659 - val_root_mean_squared_error: 0.2567
# Epoch 23/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0751 - root_mean_squared_error: 0.2739 - val_loss: 0.0656 - val_root_mean_squared_error: 0.2561
# Epoch 24/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0698 - root_mean_squared_error: 0.2642 - val_loss: 0.0639 - val_root_mean_squared_error: 0.2527
# Epoch 25/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0647 - root_mean_squared_error: 0.2541 - val_loss: 0.0621 - val_root_mean_squared_error: 0.2492
# Epoch 26/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0689 - root_mean_squared_error: 0.2623 - val_loss: 0.0626 - val_root_mean_squared_error: 0.2503
# Epoch 27/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0727 - root_mean_squared_error: 0.2694 - val_loss: 0.0625 - val_root_mean_squared_error: 0.2500
# Epoch 28/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0687 - root_mean_squared_error: 0.2621 - val_loss: 0.0599 - val_root_mean_squared_error: 0.2447
# Epoch 29/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0740 - root_mean_squared_error: 0.2718 - val_loss: 0.0624 - val_root_mean_squared_error: 0.2497
# Epoch 30/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0678 - root_mean_squared_error: 0.2604 - val_loss: 0.0588 - val_root_mean_squared_error: 0.2424
# Epoch 31/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0636 - root_mean_squared_error: 0.2522 - val_loss: 0.0645 - val_root_mean_squared_error: 0.2540
# Epoch 32/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0702 - root_mean_squared_error: 0.2650 - val_loss: 0.0583 - val_root_mean_squared_error: 0.2414
# Epoch 33/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0660 - root_mean_squared_error: 0.2567 - val_loss: 0.0599 - val_root_mean_squared_error: 0.2447
# Epoch 34/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0636 - root_mean_squared_error: 0.2521 - val_loss: 0.0585 - val_root_mean_squared_error: 0.2418
# Epoch 35/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0662 - root_mean_squared_error: 0.2572 - val_loss: 0.0567 - val_root_mean_squared_error: 0.2380
# Epoch 36/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0684 - root_mean_squared_error: 0.2615 - val_loss: 0.0577 - val_root_mean_squared_error: 0.2401
# Epoch 37/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0633 - root_mean_squared_error: 0.2515 - val_loss: 0.0568 - val_root_mean_squared_error: 0.2383
# Epoch 38/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0624 - root_mean_squared_error: 0.2496 - val_loss: 0.0551 - val_root_mean_squared_error: 0.2348
# Epoch 39/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0649 - root_mean_squared_error: 0.2547 - val_loss: 0.0565 - val_root_mean_squared_error: 0.2378
# Epoch 40/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0622 - root_mean_squared_error: 0.2492 - val_loss: 0.0543 - val_root_mean_squared_error: 0.2331
# Epoch 41/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0601 - root_mean_squared_error: 0.2450 - val_loss: 0.0529 - val_root_mean_squared_error: 0.2300
# Epoch 42/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0649 - root_mean_squared_error: 0.2548 - val_loss: 0.0549 - val_root_mean_squared_error: 0.2343
# Epoch 43/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0666 - root_mean_squared_error: 0.2577 - val_loss: 0.0527 - val_root_mean_squared_error: 0.2295
# Epoch 44/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0681 - root_mean_squared_error: 0.2606 - val_loss: 0.0524 - val_root_mean_squared_error: 0.2289
# Epoch 45/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0623 - root_mean_squared_error: 0.2495 - val_loss: 0.0518 - val_root_mean_squared_error: 0.2275
# Epoch 46/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0616 - root_mean_squared_error: 0.2482 - val_loss: 0.0509 - val_root_mean_squared_error: 0.2257
# Epoch 47/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0578 - root_mean_squared_error: 0.2399 - val_loss: 0.0506 - val_root_mean_squared_error: 0.2250
# Epoch 48/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0630 - root_mean_squared_error: 0.2508 - val_loss: 0.0513 - val_root_mean_squared_error: 0.2265
# Epoch 49/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0625 - root_mean_squared_error: 0.2499 - val_loss: 0.0517 - val_root_mean_squared_error: 0.2274
# Epoch 50/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0566 - root_mean_squared_error: 0.2378 - val_loss: 0.0516 - val_root_mean_squared_error: 0.2271
# Epoch 51/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0651 - root_mean_squared_error: 0.2551 - val_loss: 0.0514 - val_root_mean_squared_error: 0.2267
# Epoch 52/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0583 - root_mean_squared_error: 0.2415 - val_loss: 0.0499 - val_root_mean_squared_error: 0.2234
# Epoch 53/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0611 - root_mean_squared_error: 0.2471 - val_loss: 0.0499 - val_root_mean_squared_error: 0.2233
# Epoch 54/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0605 - root_mean_squared_error: 0.2458 - val_loss: 0.0497 - val_root_mean_squared_error: 0.2230
# Epoch 55/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0635 - root_mean_squared_error: 0.2519 - val_loss: 0.0501 - val_root_mean_squared_error: 0.2239
# Epoch 56/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0645 - root_mean_squared_error: 0.2539 - val_loss: 0.0544 - val_root_mean_squared_error: 0.2333
# Epoch 57/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0699 - root_mean_squared_error: 0.2641 - val_loss: 0.0496 - val_root_mean_squared_error: 0.2228
# Epoch 58/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0618 - root_mean_squared_error: 0.2482 - val_loss: 0.0490 - val_root_mean_squared_error: 0.2214
# Epoch 59/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0602 - root_mean_squared_error: 0.2454 - val_loss: 0.0494 - val_root_mean_squared_error: 0.2222
# Epoch 60/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0611 - root_mean_squared_error: 0.2471 - val_loss: 0.0486 - val_root_mean_squared_error: 0.2204
# Epoch 61/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0592 - root_mean_squared_error: 0.2434 - val_loss: 0.0487 - val_root_mean_squared_error: 0.2207
# Epoch 62/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0554 - root_mean_squared_error: 0.2353 - val_loss: 0.0486 - val_root_mean_squared_error: 0.2204
# Epoch 63/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0600 - root_mean_squared_error: 0.2449 - val_loss: 0.0478 - val_root_mean_squared_error: 0.2187
# Epoch 64/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0592 - root_mean_squared_error: 0.2433 - val_loss: 0.0484 - val_root_mean_squared_error: 0.2200
# Epoch 65/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0606 - root_mean_squared_error: 0.2462 - val_loss: 0.0477 - val_root_mean_squared_error: 0.2184
# Epoch 66/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0519 - root_mean_squared_error: 0.2276 - val_loss: 0.0479 - val_root_mean_squared_error: 0.2188
# Epoch 67/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0624 - root_mean_squared_error: 0.2498 - val_loss: 0.0495 - val_root_mean_squared_error: 0.2224
# Epoch 68/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0579 - root_mean_squared_error: 0.2406 - val_loss: 0.0486 - val_root_mean_squared_error: 0.2204
# Epoch 69/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0633 - root_mean_squared_error: 0.2515 - val_loss: 0.0484 - val_root_mean_squared_error: 0.2199
# Epoch 70/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0562 - root_mean_squared_error: 0.2369 - val_loss: 0.0487 - val_root_mean_squared_error: 0.2206
# Epoch 71/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0552 - root_mean_squared_error: 0.2349 - val_loss: 0.0471 - val_root_mean_squared_error: 0.2171
# Epoch 72/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0634 - root_mean_squared_error: 0.2514 - val_loss: 0.0481 - val_root_mean_squared_error: 0.2193
# Epoch 73/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0590 - root_mean_squared_error: 0.2427 - val_loss: 0.0472 - val_root_mean_squared_error: 0.2173
# Epoch 74/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0565 - root_mean_squared_error: 0.2377 - val_loss: 0.0468 - val_root_mean_squared_error: 0.2164
# Epoch 75/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0560 - root_mean_squared_error: 0.2365 - val_loss: 0.0464 - val_root_mean_squared_error: 0.2154
# Epoch 76/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0594 - root_mean_squared_error: 0.2435 - val_loss: 0.0466 - val_root_mean_squared_error: 0.2160
# Epoch 77/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0577 - root_mean_squared_error: 0.2401 - val_loss: 0.0468 - val_root_mean_squared_error: 0.2163
# Epoch 78/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0590 - root_mean_squared_error: 0.2428 - val_loss: 0.0473 - val_root_mean_squared_error: 0.2174
# Epoch 79/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0534 - root_mean_squared_error: 0.2310 - val_loss: 0.0469 - val_root_mean_squared_error: 0.2166
# Epoch 80/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0560 - root_mean_squared_error: 0.2365 - val_loss: 0.0464 - val_root_mean_squared_error: 0.2155
# Epoch 81/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0508 - root_mean_squared_error: 0.2250 - val_loss: 0.0466 - val_root_mean_squared_error: 0.2159
# Epoch 82/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0586 - root_mean_squared_error: 0.2420 - val_loss: 0.0454 - val_root_mean_squared_error: 0.2131
# Epoch 83/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0530 - root_mean_squared_error: 0.2301 - val_loss: 0.0477 - val_root_mean_squared_error: 0.2183
# Epoch 84/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0575 - root_mean_squared_error: 0.2397 - val_loss: 0.0454 - val_root_mean_squared_error: 0.2131
# Epoch 85/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0597 - root_mean_squared_error: 0.2442 - val_loss: 0.0455 - val_root_mean_squared_error: 0.2133
# Epoch 86/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0548 - root_mean_squared_error: 0.2341 - val_loss: 0.0451 - val_root_mean_squared_error: 0.2123
# Epoch 87/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0601 - root_mean_squared_error: 0.2449 - val_loss: 0.0456 - val_root_mean_squared_error: 0.2135
# Epoch 88/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0591 - root_mean_squared_error: 0.2430 - val_loss: 0.0453 - val_root_mean_squared_error: 0.2129
# Epoch 89/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0581 - root_mean_squared_error: 0.2410 - val_loss: 0.0456 - val_root_mean_squared_error: 0.2135
# Epoch 90/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0576 - root_mean_squared_error: 0.2399 - val_loss: 0.0451 - val_root_mean_squared_error: 0.2124
# Epoch 91/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0610 - root_mean_squared_error: 0.2468 - val_loss: 0.0446 - val_root_mean_squared_error: 0.2111
# Epoch 92/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0567 - root_mean_squared_error: 0.2378 - val_loss: 0.0442 - val_root_mean_squared_error: 0.2101
# Epoch 93/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0554 - root_mean_squared_error: 0.2352 - val_loss: 0.0449 - val_root_mean_squared_error: 0.2119
# Epoch 94/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0540 - root_mean_squared_error: 0.2323 - val_loss: 0.0455 - val_root_mean_squared_error: 0.2133
# Epoch 95/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0537 - root_mean_squared_error: 0.2317 - val_loss: 0.0452 - val_root_mean_squared_error: 0.2126
# Epoch 96/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0548 - root_mean_squared_error: 0.2342 - val_loss: 0.0447 - val_root_mean_squared_error: 0.2114
# Epoch 97/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0550 - root_mean_squared_error: 0.2344 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2122
# Epoch 98/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0558 - root_mean_squared_error: 0.2361 - val_loss: 0.0450 - val_root_mean_squared_error: 0.2121
# Epoch 99/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0560 - root_mean_squared_error: 0.2366 - val_loss: 0.0447 - val_root_mean_squared_error: 0.2115
# Epoch 100/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0585 - root_mean_squared_error: 0.2417 - val_loss: 0.0455 - val_root_mean_squared_error: 0.2132

# %% [markdown]
# ## Teste com o melhor modelo

# %%
y_pred = model.predict(X_teste)

# %%
fig, ax = plt.subplots()
ax.plot(n[len(n)-int(len(n)*tam_teste):,], y_teste, color='DeepSkyBlue', label='Valor real')
ax.plot(n[len(n)-int(len(n)*tam_teste):,], y_pred, color='Red', label='MLP')

ax.set_title("Comparação da predição da MLP com o valor real do mapa logístico \npara $r = $ " + str(r) + " utilizando a rede neural ótima")
ax.set_ylabel('x')
ax.set_xlabel('n')
ax.set_xlim(901, 1000)
    
ax.grid(True)
sns.despine()
ax.legend()

plt.show()
